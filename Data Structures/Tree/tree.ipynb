# %% [markdown]
# # Tree data structure as an Array

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# %%
class BinaryTree:
    def __init__(self, root):
        self.root = root
        self.left = None
        self.right = None

    def insertLeft(self, data):
        if self.left is None:
            self.left = BinaryTree(data)
        else:
            subtree = self.left
            self.left = BinaryTree(data)
            self.left = subtree

    def getRoot(self):
        return self.root

    def setRoot(self, root):
        self.root = root

# %%
tree = BinaryTree(5)
tree.getRoot()
# Out:
# 5
